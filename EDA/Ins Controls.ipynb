# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\suhaa\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\suhaa\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
controls=pd.read_csv('../institutional_controls_registry_sites.csv')

# %%
controls.head()
# Out:
#    MASTER_AI_ID FACILITY_ID    FACILITY_NAME STREET_ADDRESS           CITY  \
# 0           150     4120207  Clark Store 686   312 N Walnut  Hartford City
# 1           150     4120207  Clark Store 686   312 N Walnut  Hartford City
# 2           150     4120207  Clark Store 686   312 N Walnut  Hartford City
# 3           150     4120207  Clark Store 686   312 N Walnut  Hartford City
# 4          4309       02-10     M&M Landfill   129 Rose Ave      New Haven
#
#              COUNTY REGULATORY_PROGRAM CLOSURE_TYPE  \
# 0  Blackford County        Brownfields  NFA 2/11/16
# 1  Blackford County        Brownfields  NFA 2/11/16
# 2  Blackford County        Brownfields  NFA 2/11/16
# 3  Blackford County        Brownfields  NFA 2/11/16
# 4             Allen   SW Land Disposal  SWL Closure
#
#                          CONTROL_TYPE  IC_ID INSTRUMENT_ID DATE_IC_RECORDED  \
# 0  Environmental Restrictive Covenant   1143           NaN       03/10/2016
# ...

# %%
for i in range(len(controls['COUNTY'])):
    if 'County' in controls['COUNTY'][i]:
        controls['COUNTY'][i] = controls['COUNTY'][i].replace(' County', '')
# Out:
# C:\Users\suhaa\AppData\Local\Temp\ipykernel_31436\2435244807.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   controls['COUNTY'][i] = controls['COUNTY'][i].replace(' County', '')
# ...

# %%
controls.head()
# Out:
#    MASTER_AI_ID FACILITY_ID    FACILITY_NAME STREET_ADDRESS           CITY  \
# 0           150     4120207  Clark Store 686   312 N Walnut  Hartford City
# 1           150     4120207  Clark Store 686   312 N Walnut  Hartford City
# 2           150     4120207  Clark Store 686   312 N Walnut  Hartford City
# 3           150     4120207  Clark Store 686   312 N Walnut  Hartford City
# 4          4309       02-10     M&M Landfill   129 Rose Ave      New Haven
#
#       COUNTY REGULATORY_PROGRAM CLOSURE_TYPE  \
# 0  Blackford        Brownfields  NFA 2/11/16
# 1  Blackford        Brownfields  NFA 2/11/16
# 2  Blackford        Brownfields  NFA 2/11/16
# 3  Blackford        Brownfields  NFA 2/11/16
# 4      Allen   SW Land Disposal  SWL Closure
#
#                          CONTROL_TYPE  IC_ID INSTRUMENT_ID DATE_IC_RECORDED  \
# 0  Environmental Restrictive Covenant   1143           NaN       03/10/2016
# 1  Environmental Restrictive Covenant   1143           NaN       03/10/2016
# ...

# %%
controls.drop('Terminated_Date',axis=1,inplace=True)

# %%
controls.drop('VFC_URL',axis=1,inplace=True)

# %%
controls
# Out:
#       MASTER_AI_ID FACILITY_ID    FACILITY_NAME          STREET_ADDRESS  \
# 0              150     4120207  Clark Store 686            312 N Walnut
# 1              150     4120207  Clark Store 686            312 N Walnut
# 2              150     4120207  Clark Store 686            312 N Walnut
# 3              150     4120207  Clark Store 686            312 N Walnut
# 4             4309       02-10     M&M Landfill            129 Rose Ave
# ...            ...         ...              ...                     ...
# 4036        134127     6970506         Resident            520 Basca Dr
# 4037        134142     6970506        Residence          249 Ambrose St
# 4038        134143     6970506        Residence  380 - 390 E Ambrose St
# 4039        134146     6970506        Residence        389 E Ambrose St
# 4040        134148     6970506        Residence        259 E Ambrose St
#
#                CITY     COUNTY REGULATORY_PROGRAM  CLOSURE_TYPE  \
# ...

# %%
columns_to_upper=['CITY','COUNTY']
controls[columns_to_upper]=controls[columns_to_upper].apply(lambda x:x.str.upper())

# %%
controls
# Out:
#       MASTER_AI_ID FACILITY_ID    FACILITY_NAME          STREET_ADDRESS  \
# 0              150     4120207  Clark Store 686            312 N Walnut
# 1              150     4120207  Clark Store 686            312 N Walnut
# 2              150     4120207  Clark Store 686            312 N Walnut
# 3              150     4120207  Clark Store 686            312 N Walnut
# 4             4309       02-10     M&M Landfill            129 Rose Ave
# ...            ...         ...              ...                     ...
# 4036        134127     6970506         Resident            520 Basca Dr
# 4037        134142     6970506        Residence          249 Ambrose St
# 4038        134143     6970506        Residence  380 - 390 E Ambrose St
# 4039        134146     6970506        Residence        389 E Ambrose St
# 4040        134148     6970506        Residence        259 E Ambrose St
#
#                CITY     COUNTY REGULATORY_PROGRAM  CLOSURE_TYPE  \
# ...

# %%
controls_superfund=controls[controls['REGULATORY_PROGRAM']=='Superfund']

# %%
controls_superfund
# Out:
#       MASTER_AI_ID FACILITY_ID                  FACILITY_NAME  \
# 278           7267     7500016      Fort Wayne Reduction Dump
# 279           7267     7500016      Fort Wayne Reduction Dump
# 280           7267     7500016      Fort Wayne Reduction Dump
# 281           7267     7500016      Fort Wayne Reduction Dump
# 306           8818     7500026    Northside Sanitary Landfill
# ...            ...         ...                            ...
# 3505         55292     7500030                Holmes & Co Inc
# 3506         55292     7500030  Holmes & Company Incorporated
# 3682        109465     7500030  Wayne Reclamation & Recycling
# 3683        109465     7500030  Wayne Reclamation & Recycling
# 3690        110189     7500029               Airport Property
#
#           STREET_ADDRESS           CITY   COUNTY REGULATORY_PROGRAM  \
# 278       5225 Maumee Rd     FORT WAYNE    ALLEN          Superfund
# 279       5225 Maumee Rd     FORT WAYNE    ALLEN          Superfund
# ...

# %%
controls_superfund['CLOSURE_TYPE'].value_counts()
# Out:
# CLOSURE_TYPE
# SUP Order/Consent Decree 11/28/2007                27
# SUP Order/Consent Decree 7/24/2009                 16
# SUP Order/Consent Decree 9/23/1993                 15
# SUP Order/Consent Decree 4/25/1994                  9
# SUP Other-Specify 9/30/1992                         9
# SUP Other-Specify 9/26/1986                         7
# SUP                                                 4
# SUP Other-Specify 8/26/1988                         4
# SUP Order/Consent Decree 2/6/1995                   4
# SUP Other-Specify 3/31/1992                         4
# SUP Order/Consent Decree 12/1/1988                  2
# SUP Other-Specify 9/14/2012                         2
# Order/Consent Decree 11/10/1997                     2
# Superfund - Consent Decree                          2
# SUP Order/Consent Decree 2/1/1992                   2
# Consent Decree August 9, 2001\nInst #2014040272     2
# Consent Decree August 9, 2001                       2
# ...

# %%
controls['AFFECTED_MEDIA'].value_counts()
# Out:
# AFFECTED_MEDIA
# Ground Water; Subsurface Soil                                                    1303
# Ground Water                                                                     1096
# Ground Water; Subsurface Soil; Surface Soil                                       507
# Subsurface Soil                                                                   151
# Ground Water; Soil Gas (Vapor)                                                    136
# Solid Waste                                                                       136
# Subsurface Soil; Surface Soil                                                     120
# Ground Water; Soil Gas (Vapor); Subsurface Soil                                   119
# Ground Water; Surface Soil                                                         95
# Ground Water; Soil Gas (Vapor); Subsurface Soil; Surface Soil                      69
# Surface Soil                                                                       43
# ...

# %%
controls['STREET_ADDRESS'].value_counts()
# Out:
# STREET_ADDRESS
# 3005-3045 Central Ave                 40
# 340 S White River Pkwy W Dr           40
# 301 S Walnut St                       36
# 2915 Dr Martin Luther King Jr Blvd    24
# 1 Buffington Harbor Dr                18
#                                       ..
# 443 N Detroit St                       1
# 5510 W SR 46                           1
# 5884 S Wilbur Wright Rd                1
# 95 N Oak St                            1
# 259 E Ambrose St                       1
# Name: count, Length: 3280, dtype: int64

# %%
controls['CONSTITUENTS_OF_CONCERN'].value_counts()
# Out:
# CONSTITUENTS_OF_CONCERN
# Petroleum                                                                                                                                                                              1071
# VOCs - Volatile Organic Compounds                                                                                                                                                       572
# Petroleum; TPH - Total Petroleum Hydrocarbons                                                                                                                                           226
# Metals                                                                                                                                                                                  212
# Metals; VOCs - Volatile Organic Compounds                                                                                                                                               144
# ...

# %%
controls['FULL_ADDRESS'] = controls['STREET_ADDRESS'] + ', ' + controls['CITY']

# %%
for x in list(controls['FULL_ADDRESS'].unique()):
    print(x)
# Out:
# 312 N Walnut, HARTFORD CITY
# 129 Rose Ave, NEW HAVEN
# Georgetown Rd & Mitchell Rd, LAWRENCEBURG
# 11110 E SR 46, COLUMBUS
# RAILROAD RD & SR 135, MORGANTOWN
# US HWY 52 & CR 450, LEBANON
# 134 N 4th St, DECATUR
# 1113 W Eads Pkwy, LAWRENCEBURG
# 201 S Jackson St, FRANKFORT
# 205 Adams Rd, DECATUR
# 300 E Washington Blvd, FORT WAYNE
# 2304 Sherman Boulevard, FORT WAYNE
# 1011 Broadway St, FORT WAYNE
# 908 25th St, COLUMBUS
# 3202 Taylor St, FORT WAYNE
# 1509 S Macedonia Ave, MUNCIE
# 919 E 14th St, JASPER
# 330 S Clinton St, FORT WAYNE
# 1930 Indianapolis Ave, LEBANON
# 3410 S CR 650 E, COLUMBUS
# 410 E Willard St, MUNCIE
# 645 N 13TH ST, DECATUR
# 100 W Pine St, ZIONSVILLE
# 1514 W Washington St, DELPHI
# 1333 Indiana Ave, COLUMBUS
# 1616 S 10th St, COLUMBUS
# 2200 E Jackson St, MUNCIE
# 987 N US Hwy 421, GREENSBURG
# 2601 Covington Rd, FORT WAYNE
# 3651 N Clinton St, FORT WAYNE
# 6279 E State Blvd, FORT WAYNE
# 2300 W Jefferson Blvd, FORT WAYNE
# 5929 Moeller Rd, FORT WAYNE
# ...

# %%
controls['FULL_ADDRESS'].nunique()
# Out:
# 3286

# %%
controls.to_csv('institutional_controls.csv')

# %%
def process(s):
    if isinstance(s, str):
        return ','.join(s.split(';'))
    else:
        return s

def search_contamination(address, contamination_data):
    # Convert address to lowercase for case-insensitive search
    address_lower = address.lower()
    
    # Filter the dataframe for rows where the address matches (case-insensitive)
    matches = contamination_data[contamination_data['FULL_ADDRESS'].str.lower().str.contains(address_lower)]
    
    if matches.empty:
        return "No contamination records found for this address."
    else:
        results = []
        for _, row in matches.iterrows():
            result = f"Facility Name: {row['FACILITY_NAME']}\n"
            result += f"Address: {row['FULL_ADDRESS']}\n"
            result += f"Contamination Recorded: {row['DATE_IC_RECORDED']}\n"
            result += f"Affected Media: {row['AFFECTED_MEDIA']}\n"
            constituents_of_concern=process(row['CONSTITUENTS_OF_CONCERN'])
            result += f"Constituents of Concern: {constituents_of_concern}\n"
            result += f"Restriction Coverage: {row['RESTRICTION_COVERAGE']}\n"
            result += "-" * 45 + "\n"
            results.append(result)
        
        return "\n".join(results)

# Example usage:
print(search_contamination("5225 Maumee Rd, FORT WAYNE",controls))
# Out:
# Facility Name: Fort Wayne Reduction Dump
# Address: 5225 Maumee Rd, FORT WAYNE
# Contamination Recorded: 05/29/2002
# Affected Media: Ground Water; Subsurface Soil
# Constituents of Concern: Metals, Other, PAH - Polynuclear Aromatic Hydrocarbons, PCB - Polychlorinated Byphenols, VOCs - Volatile Organic Compounds
# Restriction Coverage: Entire Property; Portion of Property
# ---------------------------------------------
#
# Facility Name: Fort Wayne Reduction Dump
# Address: 5225 Maumee Rd, FORT WAYNE
# Contamination Recorded: 05/29/2002
# Affected Media: Ground Water; Subsurface Soil
# Constituents of Concern: Metals, Other, PAH - Polynuclear Aromatic Hydrocarbons, PCB - Polychlorinated Byphenols, VOCs - Volatile Organic Compounds
# Restriction Coverage: Entire Property; Portion of Property
# ---------------------------------------------
#
# Facility Name: Fort Wayne Reduction Dump
# Address: 5225 Maumee Rd, FORT WAYNE
# Contamination Recorded: 05/16/2012
# ...

# %%
controls
# Out:
#       MASTER_AI_ID FACILITY_ID    FACILITY_NAME          STREET_ADDRESS  \
# 0              150     4120207  Clark Store 686            312 N Walnut
# 1              150     4120207  Clark Store 686            312 N Walnut
# 2              150     4120207  Clark Store 686            312 N Walnut
# 3              150     4120207  Clark Store 686            312 N Walnut
# 4             4309       02-10     M&M Landfill            129 Rose Ave
# ...            ...         ...              ...                     ...
# 4036        134127     6970506         Resident            520 Basca Dr
# 4037        134142     6970506        Residence          249 Ambrose St
# 4038        134143     6970506        Residence  380 - 390 E Ambrose St
# 4039        134146     6970506        Residence        389 E Ambrose St
# 4040        134148     6970506        Residence        259 E Ambrose St
#
#                CITY     COUNTY REGULATORY_PROGRAM  CLOSURE_TYPE  \
# ...

# %%
zip_codes=pd.read_csv('../indiana_zip_codes.csv')

# %%
zip_codes
# Out:
#       County FIPS   County  ZIP Code  Percent of ZIP Code in this County  \
# 0               1    Adams     46711                               100.0
# 1               1    Adams     46714                                 4.9
# 2               1    Adams     46733                                98.2
# 3               1    Adams     46740                                97.1
# 4               1    Adams     46772                               100.0
# ...           ...      ...       ...                                 ...
# 1091          183  Whitley     46764                                87.5
# 1092          183  Whitley     46783                                16.2
# 1093          183  Whitley     46787                                92.6
# 1094          183  Whitley     46818                                 2.2
# 1095          183  Whitley     46962                                 1.9
#
#       Percent of County in this ZIP Code
# 0                                    17.6
# ...

# %% [markdown]
# ### Since Ins Controls Data doesn't have Zip Codes, including top zip code to the counties based on population

# %%
max_popln_zip_codes = zip_codes.loc[zip_codes.groupby('County')['Percent of ZIP Code in this County'].idxmax()]

# Only keep necessary columns for output
max_popln_zip_codes = max_popln_zip_codes[['County', 'ZIP Code', 'Percent of ZIP Code in this County']]

# %%
max_popln_zip_codes
# Out:
#            County  ZIP Code  Percent of ZIP Code in this County
# 0           Adams     46711                               100.0
# 10          Allen     46741                               100.0
# 40    Bartholomew     47203                               100.0
# 55         Benton     47971                               100.0
# 62      Blackford     47348                                99.3
# ...           ...       ...                                 ...
# 1040   Washington     47167                               100.0
# 1045        Wayne     47330                               100.0
# 1058        Wells     46731                               100.0
# 1080        White     47929                               100.0
# 1090      Whitley     46725                                97.9
#
# [92 rows x 3 columns]

# %%
# max_popln_zip_codes.to_csv('max_popln_zip_codes.csv')

# %%
max_popln_zip_codes['County']=max_popln_zip_codes['County'].str.upper()

# %%
county_zip_dict=dict(zip(max_popln_zip_codes['County'],max_popln_zip_codes['ZIP Code']))

# %%
county_zip_dict
# Out:
# {'ADAMS': 46711,
#  'ALLEN': 46741,
#  'BARTHOLOMEW': 47203,
#  'BENTON': 47971,
#  'BLACKFORD': 47348,
#  'BOONE': 46052,
#  'BROWN': 47448,
#  'CARROLL': 46913,
#  'CASS': 46988,
#  'CLARK': 47111,
#  'CLAY': 47840,
#  'CLINTON': 46039,
#  'CRAWFORD': 47116,
#  'DAVIESS': 47501,
#  'DEKALB': 46721,
#  'DEARBORN': 47022,
#  'DECATUR': 47240,
#  'DELAWARE': 47303,
#  'DUBOIS': 47521,
#  'ELKHART': 46507,
#  'FAYETTE': 47331,
#  'FLOYD': 47150,
#  'FOUNTAIN': 47949,
#  'FRANKLIN': 47010,
#  'FULTON': 46975,
#  'GIBSON': 47647,
#  'GRANT': 46928,
#  'GREENE': 47424,
#  'HAMILTON': 46030,
#  'HANCOCK': 46140,
#  'HARRISON': 47110,
#  'HENDRICKS': 46122,
#  'HENRY': 47362,
#  'HOWARD': 46936,
#  'HUNTINGTON': 46750,
#  'JACKSON': 47220,
#  'JASPER': 46392,
#  'JAY': 47326,
#  'JEFFERSON': 47243,
#  'JENNINGS': 47223,
#  'JOHNSON': 46106,
#  'KNOX': 47512,
#  'KOSCIUSKO': 46508,
#  'LAGRANGE': 46565,
#  'LAPORTE': 46340,
#  'LAKE': 46303,
#  'LAWRENCE': 47446,
#  'MADISON': 46011,
# ...

# %%
controls['ZIP_CODE']=controls['COUNTY'].map(county_zip_dict).fillna(0).astype(int)

# %%
controls
# Out:
#       MASTER_AI_ID FACILITY_ID    FACILITY_NAME          STREET_ADDRESS  \
# 0              150     4120207  Clark Store 686            312 N Walnut
# 1              150     4120207  Clark Store 686            312 N Walnut
# 2              150     4120207  Clark Store 686            312 N Walnut
# 3              150     4120207  Clark Store 686            312 N Walnut
# 4             4309       02-10     M&M Landfill            129 Rose Ave
# ...            ...         ...              ...                     ...
# 4036        134127     6970506         Resident            520 Basca Dr
# 4037        134142     6970506        Residence          249 Ambrose St
# 4038        134143     6970506        Residence  380 - 390 E Ambrose St
# 4039        134146     6970506        Residence        389 E Ambrose St
# 4040        134148     6970506        Residence        259 E Ambrose St
#
#                CITY     COUNTY REGULATORY_PROGRAM  CLOSURE_TYPE  \
# ...

# %%
controls = controls[controls['ZIP_CODE'] != 0]

# %%
controls
# Out:
#       MASTER_AI_ID FACILITY_ID    FACILITY_NAME          STREET_ADDRESS  \
# 0              150     4120207  Clark Store 686            312 N Walnut
# 1              150     4120207  Clark Store 686            312 N Walnut
# 2              150     4120207  Clark Store 686            312 N Walnut
# 3              150     4120207  Clark Store 686            312 N Walnut
# 4             4309       02-10     M&M Landfill            129 Rose Ave
# ...            ...         ...              ...                     ...
# 4036        134127     6970506         Resident            520 Basca Dr
# 4037        134142     6970506        Residence          249 Ambrose St
# 4038        134143     6970506        Residence  380 - 390 E Ambrose St
# 4039        134146     6970506        Residence        389 E Ambrose St
# 4040        134148     6970506        Residence        259 E Ambrose St
#
#                CITY     COUNTY REGULATORY_PROGRAM  CLOSURE_TYPE  \
# ...

# %%
controls['CONSTITUENTS_OF_CONCERN']=controls['CONSTITUENTS_OF_CONCERN'].apply(process)
# Out:
# C:\Users\suhaa\AppData\Local\Temp\ipykernel_31436\1437020026.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   controls['CONSTITUENTS_OF_CONCERN']=controls['CONSTITUENTS_OF_CONCERN'].apply(process)

# %%
controls['CONTROL_METHOD']=controls['CONTROL_METHOD'].apply(process)
# Out:
# C:\Users\suhaa\AppData\Local\Temp\ipykernel_31436\2035585794.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   controls['CONTROL_METHOD']=controls['CONTROL_METHOD'].apply(process)

# %%
# controls.to_csv('ins_controls_indiana.csv')

# %%
def search_contamination(address, contamination_data):
    address_lower = address.lower() 

    matches = contamination_data[contamination_data['FULL_ADDRESS'].str.lower().str.contains(address_lower)]
    
    if matches.empty:
        return "No contamination records found for this address."
    else:
        results = []
        for _, row in matches.iterrows():
            result = f"Facility Name: {row['FACILITY_NAME']}\n"
            result += f"Address: {row['FULL_ADDRESS']}\n"
            result += f"Contamination Recorded: {row['DATE_IC_RECORDED']}\n"
            result += f"Affected Media: {row['AFFECTED_MEDIA']}\n"
            constituents_of_concern=process(row['CONSTITUENTS_OF_CONCERN'])
            result += f"Constituents of Concern: {constituents_of_concern}\n"
            result += f"Restriction Coverage: {row['RESTRICTION_COVERAGE']}\n"
            result += f"Control Recommended : {row['CONTROL_METHOD']}\n"
            result += "-" * 45 + "\n"
            results.append(result)
        
        return "\n".join(results)

# %%
print(search_contamination("129 Rose Ave, NEW HAVEN",controls))
# Out:
# Facility Name: M&M Landfill
# Address: 129 Rose Ave, NEW HAVEN
# Contamination Recorded: 05/12/2015
# Affected Media: Solid Waste
# Constituents of Concern: nan
# Restriction Coverage: Entire Property
# Control Recommended :Soil or Vegetative Cap
# ---------------------------------------------

# %%
def search_contamination_by_zip(zipcode, contamination_data):
    zipcode_str = str(zipcode)  # Ensure the zipcode is treated as a string
    
    # Filter rows where the ZIP_CODE matches exactly
    matches = contamination_data[contamination_data['ZIP_CODE'].astype(str) == zipcode_str]
    
    if matches.empty:
        return "No contamination records found for this ZIP code."
    else:
        results = []
        for _, row in matches.iterrows():
            result = f"Facility Name: {row['FACILITY_NAME']}\n"
            result += f"Address: {row['FULL_ADDRESS']}\n"
            result += f"Contamination Recorded: {row['DATE_IC_RECORDED']}\n"
            result += f"Affected Media: {row['AFFECTED_MEDIA']}\n"
            constituents_of_concern = process(row['CONSTITUENTS_OF_CONCERN'])
            result += f"Constituents of Concern: {constituents_of_concern}\n"
            result += f"Restriction Coverage: {row['RESTRICTION_COVERAGE']}\n"
            result += f"Control Recommended: {row['CONTROL_METHOD']}\n"
            result += "-" * 45 + "\n"
            results.append(result)
        
        return "\n".join(results)

# %%
print(search_contamination_by_zip(47348, controls))
# Out:
# Facility Name: Clark Store 686
# Address: 312 N Walnut, HARTFORD CITY
# Contamination Recorded: 03/10/2016
# Affected Media: Ground Water
# Constituents of Concern: Petroleum
# Restriction Coverage: Entire Property
# Control Recommended: Ground Water Use Restriction
# ---------------------------------------------
#
# Facility Name: Clark Store 686
# Address: 312 N Walnut, HARTFORD CITY
# Contamination Recorded: 03/10/2016
# Affected Media: Ground Water
# Constituents of Concern: Petroleum
# Restriction Coverage: Entire Property
# Control Recommended: Ground Water Use Restriction
# ---------------------------------------------
#
# Facility Name: Clark Store 686
# Address: 312 N Walnut, HARTFORD CITY
# Contamination Recorded: 03/10/2016
# Affected Media: Ground Water
# Constituents of Concern: VOCs - Volatile Organic Compounds
# Restriction Coverage: Entire Property
# Control Recommended: Ground Water Use Restriction
# ---------------------------------------------
#
# ...
