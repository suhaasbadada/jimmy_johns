# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\suhaa\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\suhaa\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
df=pd.read_csv('../superfunds.csv')

# %%
df
# Out:
#       Region               City      County          State Zip Code  \
# 0          1          FAIRHAVEN     BRISTOL  Massachusetts     2719
# 1          1        LONDONDERRY  ROCKINGHAM  New Hampshire     3053
# 2          1           HOLBROOK     NORFOLK  Massachusetts     2343
# 3          1        BARKHAMSTED  LITCHFIELD    Connecticut     6063
# 4          1       BEACON FALLS   NEW HAVEN    Connecticut     6403
# ...      ...                ...         ...            ...      ...
# 1900      10          VANCOUVER       CLARK     Washington    98663
# 1901      10          VANCOUVER       CLARK     Washington    98661
# 1902      10               KENT        KING     Washington    98031
# 1903      10  BAINBRIDGE ISLAND      KITSAP     Washington    98110
# 1904      10             YAKIMA      YAKIMA     Washington    98902
#
#             EPA ID                                 Site Name NPL Status
# 0     MAD001026319                          ATLAS TACK CORP.      Final
# ...

# %%
df[df['State']=='Indiana']
# Out:
#       Region            City       County    State    Zip Code        EPA ID  \
# 953        5        GRIFFITH         LAKE  Indiana       46319  IND016360265
# 967        5      SOUTH BEND   ST. JOSEPH  Indiana       46619  IND980904379
# 972        5     BLOOMINGTON       MONROE  Indiana       47401  IND006418651
# 979        5        ANDERSON      MADISON  Indiana       46016  INN000510915
# 986        5       WESTVILLE     LA PORTE  Indiana       46391  IND005480462
# 989        5    INDIANAPOLIS       MARION  Indiana       46222  IND016395899
# 1002       5      LOGANSPORT         CASS  Indiana       46947  INN000510272
# 1004       5        COLUMBUS  BARTHOLOMEW  Indiana       47201  IND980607626
# 1005       5         ELKHART      ELKHART  Indiana       46514  IND000715490
# 1006       5          KOKOMO       HOWARD  Indiana       46902  IND001213503
# 1014       5       MISHAWAKA   ST. JOSEPH  Indiana       46544  IND980607881
# ...

# %% [markdown]
# ### Notes

# %% [markdown]
# Geographic Distribution: <br>
# The Superfund sites are spread across various counties in Indiana, including Lake, St. Joseph, Monroe, Madison, Marion, Cass, Bartholomew, Elkhart, Howard, Vigo, Boone, Allen, Owen, Vanderburgh, Kosciusko, Grant, Spencer, Morgan, Hancock, Knox, Jackson, Tippecanoe, Porter, and Whitley counties. This indicates that environmental contamination issues are not confined to one specific area but are distributed throughout the state. <br>
#
# Site Types:<br>
# The list includes various types of contaminated sites, such as:<br>
# Landfills (e.g., Gary Development Landfill, Northside Sanitary Landfill)<br>
# Industrial sites (e.g., Continental Steel Corp., Federated Metals Corp Whiting)<br>
# Dump sites (e.g., Fort Wayne Reduction Dump, Marion (Bragg) Dump)<br>
# Groundwater contamination plumes (e.g., Broadway Street Corridor Groundwater Contamination, Keystone Corridor Ground Water Contamination)<br>
# Chemical plants (e.g., American Chemical Service, Inc., Reilly Tar & Chemical Corp.)<br>
# NPL Status:<br>
# Most sites are listed as "Final" on the National Priorities List (NPL), indicating they have been formally added to the Superfund program for long-term remedial action. However, some sites are listed as "Deleted," meaning they have been successfully cleaned up and removed from the NPL. One site (Town of Pines Groundwater Plume) is listed as "Non-NPL," suggesting it may be addressed through other environmental programs.<br>
# Urban vs. Rural:<br>
# The list includes sites in major cities like Indianapolis, Fort Wayne, and South Bend, as well as smaller towns and rural areas, indicating that contamination issues affect both urban and rural communities in Indiana.<br>
# Historical Industrial Activity:<br>
# Many sites appear to be related to historical industrial activities, such as metal processing, chemical manufacturing, and waste disposal, reflecting Indiana's industrial heritage.<br>
# Groundwater Contamination:<br>
# There are several entries specifically mentioning groundwater contamination, highlighting the importance of protecting water resources and the long-term effects of certain types of pollution.<br>
# Cleanup Progress:<br>
# The presence of "Deleted" sites demonstrates that successful cleanups have occurred in Indiana, though many sites remain on the active NPL.<br>
# Diverse Contaminants:<br>
# While specific contaminants aren't listed, the variety of site types suggests a range of pollutants, potentially including heavy metals, organic chemicals, and other hazardous substances.<br>
# Long-term Environmental Challenges:<br>
# The list includes sites that have been known for decades (e.g., some sites have EPA ID numbers from the 1980s), indicating the long-term nature of some environmental remediation efforts.<br>
# Environmental Justice Considerations:<br>
# Some sites are located in urban areas or near residential communities (e.g., Jacobsville Neighborhood Soil Contamination), which may raise environmental justice concerns about the impact on local populations.<br>
